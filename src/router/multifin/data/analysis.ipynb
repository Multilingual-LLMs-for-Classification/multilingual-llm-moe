# %%
import numpy as np
import pandas as pd

# %%
en = pd.read_csv("test_en.csv")
df = pd.DataFrame(en)
lang_group = df.groupby('label').agg(label_count =('label', 'count'))

# %%
print(lang_group)
# Out:
#                        label_count
# label
# Business & Management           12
# Finance                         21
# Government & Controls            6
# Industry                         9
# Tax & Accounting                20
# Technology                      12

# %%
df
# Out:
#                                                  text                  label  \
# 0         Hospitality Investment Strategies in Greece               Industry
# 1      Deal summary Family Piri / Ruukki Construction                Finance
# 2   Rethinking logistics operations – a strategic ...               Industry
# 3   Provisions of the simplified APA procedure to ...       Tax & Accounting
# 4            Healthcare revenue cycles remain complex               Industry
# ..                                                ...                    ...
# 75                    Out-of-Band (OOB) SQL Injection             Technology
# 76                    Transforming digital operations             Technology
# 77         Deal summary Solita Oy / Vaaka Partners Oy                Finance
# 78                           Tax reporting & strategy       Tax & Accounting
# 79  Looking good on paper:  From first to second g...  Business & Management
#
#        lang            id
# ...
